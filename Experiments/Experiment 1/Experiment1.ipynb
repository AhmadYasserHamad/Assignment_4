# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadYasserHamad/Assignment_4/blob/main/Experiment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from opendatasets) (4.67.1)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (from opendatasets) (1.7.4.5)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from opendatasets) (8.3.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2025.11.12)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (1.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (0.5.1)
# Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
import pandas as pd
import opendatasets as od
df = pd.read_csv("data.csv")
# Quick look at the dataset
print(df.head())
print(df.info())
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
# drop un named column in data
df = df.drop('Unnamed: 32', axis=1)
print("\nDropped 'Unnamed: 32' column (empty column)")

# Remove non-feature columns (id and diagnosis for unsupervised learning) and id have no meaning
X = df.drop(['id', 'diagnosis'], axis=1, errors='ignore')

print(f"\nRemaining columns: {X.columns.tolist()}")
print(f"Features shape: {X.shape}")

# Normalize the features using StandardScaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_normalized = scaler.fit_transform(X)

# Convert back to DataFrame for easier viewing
normalized_df = pd.DataFrame(X_normalized, columns=X.columns)

print("\n" + "="*50)
print("NORMALIZATION COMPLETE")
print("="*50)
print(f"\nOriginal data statistics:")
print(X.describe())
print(f"\nNormalized data statistics:")
print(normalized_df.describe())

print(f"\nNormalized data shape: {X_normalized.shape}")

# Display first few rows of normalized data
print("\nFirst 5 rows of normalized data:")
print(normalized_df.head())
# Out:
# Dropped 'Unnamed: 32' column (empty column)
#
# Remaining columns: ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']
# Features shape: (569, 30)
#
# ==================================================
# NORMALIZATION COMPLETE
# ==================================================
#
# Original data statistics:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]
#
# Normalized data statistics:
#         radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean  -1.373633e-16  6.868164e-17   -1.248757e-16 -2.185325e-16
# std    1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%    4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max    3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count     5.690000e+02      5.690000e+02    5.690000e+02         5.690000e+02
# mean     -8.366672e-16      1.873136e-16    4.995028e-17        -4.995028e-17
# std       1.000880e+00      1.000880e+00    1.000880e+00         1.000880e+00
# min      -3.112085e+00     -1.610136e+00   -1.114873e+00        -1.261820e+00
# 25%      -7.109628e-01     -7.470860e-01   -7.437479e-01        -7.379438e-01
# 50%      -3.489108e-02     -2.219405e-01   -3.422399e-01        -3.977212e-01
# 75%       6.361990e-01      4.938569e-01    5.260619e-01         6.469351e-01
# max       4.770911e+00      4.568425e+00    4.243589e+00         3.927930e+00
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count   5.690000e+02            5.690000e+02  ...  5.690000e+02
# mean    1.748260e-16            4.745277e-16  ... -8.241796e-16
# std     1.000880e+00            1.000880e+00  ...  1.000880e+00
# min    -2.744117e+00           -1.819865e+00  ... -1.726901e+00
# 25%    -7.032397e-01           -7.226392e-01  ... -6.749213e-01
# 50%    -7.162650e-02           -1.782793e-01  ... -2.690395e-01
# 75%     5.307792e-01            4.709834e-01  ...  5.220158e-01
# max     4.484751e+00            4.910919e+00  ...  4.094189e+00
#
#        texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# count   5.690000e+02     5.690000e+02  569.000000      5.690000e+02
# mean    1.248757e-17    -3.746271e-16    0.000000     -2.372638e-16
# std     1.000880e+00     1.000880e+00    1.000880      1.000880e+00
# min    -2.223994e+00    -1.693361e+00   -1.222423     -2.682695e+00
# 25%    -7.486293e-01    -6.895783e-01   -0.642136     -6.912304e-01
# 50%    -4.351564e-02    -2.859802e-01   -0.341181     -4.684277e-02
# 75%     6.583411e-01     5.402790e-01    0.357589      5.975448e-01
# max     3.885905e+00     4.287337e+00    5.930172      3.955374e+00
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count       5.690000e+02     5.690000e+02          5.690000e+02
# mean       -3.371644e-16     7.492542e-17          2.247763e-16
# std         1.000880e+00     1.000880e+00          1.000880e+00
# min        -1.443878e+00    -1.305831e+00         -1.745063e+00
# 25%        -6.810833e-01    -7.565142e-01         -7.563999e-01
# 50%        -2.695009e-01    -2.182321e-01         -2.234689e-01
# 75%         5.396688e-01     5.311411e-01          7.125100e-01
# max         5.112877e+00     4.700669e+00          2.685877e+00
#
#        symmetry_worst  fractal_dimension_worst
# count    5.690000e+02             5.690000e+02
# mean     2.622390e-16            -5.744282e-16
# std      1.000880e+00             1.000880e+00
# min     -2.160960e+00            -1.601839e+00
# 25%     -6.418637e-01            -6.919118e-01
# 50%     -1.274095e-01            -2.164441e-01
# 75%      4.501382e-01             4.507624e-01
# max      6.046041e+00             6.846856e+00
#
# [8 rows x 30 columns]
#
# Normalized data shape: (569, 30)
#
# First 5 rows of normalized data:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                2.255747  ...      1.886690      -1.359293         2.303601
# 1               -0.868652  ...      1.805927      -0.369203         1.535126
# 2               -0.398008  ...      1.511870      -0.023974         1.347475
# 3                4.910919  ...     -0.281464       0.133984        -0.249939
# 4               -0.562450  ...      1.298575      -1.466770         1.338539
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    2.001237          1.307686           2.616665         2.109526
# 1    1.890489         -0.375612          -0.430444        -0.146749
# 2    1.456285          0.527407           1.082932         0.854974
# 3   -0.550021          3.394275           3.893397         1.989588
# 4    1.220724          0.220556          -0.313395         0.613179
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0              2.296076        2.750622                 1.937015
# 1              1.087084       -0.243890                 0.281190
# 2              1.955000        1.152255                 0.201391
# 3              2.175786        6.046041                 4.935010
# 4              0.729259       -0.868353                -0.397100
#
# [5 rows x 30 columns]

# %%
import numpy as np

def kmeans_plusplus_init(X, k, random_state=None):
    if random_state is not None:
        np.random.seed(random_state)

    n_samples, n_features = X.shape
    centers = np.zeros((k, n_features))

    # Step 1: Choose first center randomly from data points
    first_center_idx = np.random.randint(0, n_samples)
    centers[0] = X[first_center_idx]
    print(f"Center 1 initialized at index {first_center_idx}")

    # Step 2: Choose remaining k-1 centers
    for i in range(1, k):
        # Calculate distance from each point to nearest existing center
        distances = np.zeros(n_samples)

        for j in range(n_samples):
            # Calculate distances to all existing centers
            dist_to_centers = np.zeros(i)
            for c in range(i):
                dist_to_centers[c] = np.sum((X[j] - centers[c]) ** 2)

            # Store minimum distance (squared distance to nearest center)
            distances[j] = np.min(dist_to_centers)

        # Choose next center with probability proportional to distance squared
        probabilities = distances / np.sum(distances)
        next_center_idx = np.random.choice(n_samples, p=probabilities)
        centers[i] = X[next_center_idx]
        print(f"Center {i+1} initialized at index {next_center_idx}")

    print(f"\nK-means++ initialization complete!")
    print(f"Initial centers shape: {centers.shape}")

    return centers
k = 2
initial_centers = kmeans_plusplus_init(X_normalized , k=k, random_state=42)

print(f"\nInitial Centers:")
print(initial_centers)
# Out:
# Center 1 initialized at index 102
# Center 2 initialized at index 432
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
#
# Initial Centers:
# [[-0.5530585   0.28631105 -0.60751564 -0.55798194 -1.15503513 -1.21215527
#   -0.81568788 -0.8052661  -0.2651265  -0.85447642 -0.76793904  0.64254367
#   -0.83316584 -0.5644996  -0.65368614 -1.08314703 -0.70305211 -0.81090835
#   -0.73522485 -0.85594642 -0.60658404  1.16641373 -0.67557894 -0.58500369
#   -0.87972471 -1.05373391 -0.75651421 -0.61357437 -0.33448538 -0.84042616]
#  [ 1.71905507  0.05825847  1.72302589  1.69255646  1.20552258  0.84445927
#    1.56310249  1.98564279 -0.31989066 -0.32145729  0.10079781 -0.39163235
#    0.07026503  0.26738504  0.68203468  0.09343955  0.78138781  1.18475716
#    0.48040333  0.07946914  1.19296315 -0.09888253  1.15386726  1.05196463
#    1.4961806   0.25404212  1.24069484  1.56367679  0.21232446 -0.17709882]]

# %%
def kmeans(X, k, centers, epochs, tolerance=1e-6, verbose=True):
    """K-means clustering algorithm"""
    n_samples, n_features = X.shape
    labels = np.zeros(n_samples, dtype=int)
    inertia_history = []

    if verbose:
        print(f"Starting K-means algorithm...")
        print(f"Data shape: {X.shape}")
        print(f"Number of clusters (k): {k}")
        print(f"Max epochs: {epochs}")
        print(f"Convergence tolerance: {tolerance}\n")

    for epoch in range(epochs):
        # Assignment step
        for i in range(n_samples):
            distances = np.zeros(k)
            for j in range(k):
                distances[j] = np.sum((X[i] - centers[j]) ** 2)
            labels[i] = np.argmin(distances)

        # Update step
        new_centers = np.zeros((k, n_features))
        for j in range(k):
            cluster_points = X[labels == j]
            if len(cluster_points) > 0:
                new_centers[j] = np.mean(cluster_points, axis=0)
            else:
                new_centers[j] = centers[j]

        # Calculate inertia
        inertia = 0
        for i in range(n_samples):
            inertia += np.sum((X[i] - centers[labels[i]]) ** 2)
        inertia_history.append(inertia)

        # Check convergence
        center_shift = np.sum(np.abs(new_centers - centers))

        if verbose:
            print(f"Epoch {epoch + 1}/{epochs} - Inertia: {inertia:.4f} - Center shift: {center_shift:.6f}")

        if center_shift < tolerance:
            if verbose:
                print(f"\nConverged at epoch {epoch + 1}! (Center shift {center_shift:.6f} < tolerance {tolerance})")
            centers = new_centers
            break

        centers = new_centers

    if verbose:
        print(f"\nK-means complete!")
        print(f"Final inertia: {inertia_history[-1]:.4f}")

        # Print cluster sizes
        print(f"\nCluster sizes:")
        for i in range(k):
            cluster_size = np.sum(labels == i)
            print(f"Cluster {i}: {cluster_size} points")

    return centers, labels, inertia_history



# Example usage
# Assuming normalized_df is available from previous code
X_data = normalized_df.values

# Parameters
k = 2
epochs = 100

# Initialize centers using K-means++
print("="*50)
print("K-MEANS++ INITIALIZATION")
print("="*50)
initial_centers = kmeans_plusplus_init(X_data, k=k, random_state=42)

# Run K-means
print("\n" + "="*50)
print("K-MEANS CLUSTERING")
print("="*50)
final_centers, labels, inertia_history = kmeans(X_data, k, initial_centers, epochs)

print("\n" + "="*50)
print("RESULTS")
print("="*50)
print(f"Final centers shape: {final_centers.shape}")
print(f"Labels shape: {labels.shape}")
print(f"Unique labels: {np.unique(labels)}")
# Out:
# ==================================================
# K-MEANS++ INITIALIZATION
# ==================================================
# Center 1 initialized at index 102
# Center 2 initialized at index 432
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
#
# ==================================================
# K-MEANS CLUSTERING
# ==================================================
# Starting K-means algorithm...
# Data shape: (569, 30)
# Number of clusters (k): 2
# Max epochs: 100
# Convergence tolerance: 1e-06
#
# Epoch 1/100 - Inertia: 16420.4473 - Center shift: 27.497835
# Epoch 2/100 - Inertia: 11599.9686 - Center shift: 0.834528
# Epoch 3/100 - Inertia: 11595.6965 - Center shift: 0.172283
# Epoch 4/100 - Inertia: 11595.5266 - Center shift: 0.000000
#
# Converged at epoch 4! (Center shift 0.000000 < tolerance 1e-06)
#
# K-means complete!
# Final inertia: 11595.5266
#
# Cluster sizes:
# Cluster 0: 375 points
# Cluster 1: 194 points
#
# ==================================================
# RESULTS
# ==================================================
# Final centers shape: (2, 30)
# Labels shape: (569,)
# Unique labels: [0 1]

# %%
import matplotlib.pyplot as plt
def calculate_distortion(X, centers, labels):
    """
    Calculate distortion (average squared distance to cluster center)
    Distortion = WCSS / n_samples
    """
    n_samples = len(X)
    distortion = 0

    for i in range(n_samples):
        distortion += np.sum((X[i] - centers[labels[i]]) ** 2)

    return distortion / n_samples


def elbow_method(X, k_range, epochs=100, random_state=42):
    """
    Apply elbow method to find optimal K

    Parameters:
    -----------
    X : numpy array
        The data points
    k_range : range or list
        Range of K values to try
    epochs : int
        Maximum iterations for each K-means run
    random_state : int
        Random seed for reproducibility

    Returns:
    --------
    wcss_list : list
        Within-Cluster Sum of Squares (Inertia) for each K
    distortion_list : list
        Distortion for each K
    inertia_histories : list
        List of inertia histories for each K
    """
    wcss_list = []
    distortion_list = []
    inertia_histories = []

    print("="*60)
    print("ELBOW METHOD - Finding Optimal K")
    print("="*60)

    for k in k_range:
        print(f"\n{'='*60}")
        print(f"Testing K = {k}")
        print('='*60)

        # Initialize centers
        initial_centers = kmeans_plusplus_init(X, k, random_state=random_state)

        # Run K-means (verbose=False to reduce output)
        final_centers, labels, inertia_history = kmeans(X, k, initial_centers, epochs, verbose=False)

        # Get final WCSS (inertia)
        final_wcss = inertia_history[-1]

        # Calculate distortion
        distortion = calculate_distortion(X, final_centers, labels)

        wcss_list.append(final_wcss)
        distortion_list.append(distortion)
        inertia_histories.append(inertia_history)

        print(f"K = {k}: WCSS (Inertia) = {final_wcss:.4f}, Distortion = {distortion:.4f}, Converged in {len(inertia_history)} epochs")

    return wcss_list, distortion_list, inertia_histories


# Run elbow method
X_data = normalized_df.values
k_range = range(1, 11)  # Test K from 1 to 10

wcss_list, distortion_list, inertia_histories = elbow_method(X_data, k_range, epochs=100, random_state=42)

# Plot results
print("\n" + "="*60)
print("PLOTTING RESULTS")
print("="*60)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Plot 1: WCSS (Inertia)
axes[0].plot(k_range, wcss_list, 'bo-', linewidth=2, markersize=8)
axes[0].set_xlabel('Number of Clusters (K)', fontsize=12)
axes[0].set_ylabel('WCSS (Within-Cluster Sum of Squares)', fontsize=12)
axes[0].set_title('Elbow Method - WCSS (Inertia)', fontsize=14, fontweight='bold')
axes[0].grid(True, alpha=0.3)
axes[0].set_xticks(k_range)

# Plot 2: Distortion
axes[1].plot(k_range, distortion_list, 'ro-', linewidth=2, markersize=8)
axes[1].set_xlabel('Number of Clusters (K)', fontsize=12)
axes[1].set_ylabel('Distortion (Average Squared Distance)', fontsize=12)
axes[1].set_title('Elbow Method - Distortion', fontsize=14, fontweight='bold')
axes[1].grid(True, alpha=0.3)
axes[1].set_xticks(k_range)

# Plot 3: Both on same plot (normalized)
# Normalize both metrics to 0-1 range for comparison
wcss_normalized = (wcss_list - np.min(wcss_list)) / (np.max(wcss_list) - np.min(wcss_list))
distortion_normalized = (distortion_list - np.min(distortion_list)) / (np.max(distortion_list) - np.min(distortion_list))

axes[2].plot(k_range, wcss_normalized, 'bo-', linewidth=2, markersize=8, label='WCSS (Inertia)')
axes[2].plot(k_range, distortion_normalized, 'ro-', linewidth=2, markersize=8, label='Distortion')
axes[2].set_xlabel('Number of Clusters (K)', fontsize=12)
axes[2].set_ylabel('Normalized Value', fontsize=12)
axes[2].set_title('Elbow Method - Combined (Normalized)', fontsize=14, fontweight='bold')
axes[2].grid(True, alpha=0.3)
axes[2].set_xticks(k_range)
axes[2].legend(fontsize=10)

plt.tight_layout()
plt.show()

print("\nElbow Method Complete!")
print("\nInterpretation:")
print("- Look for the 'elbow' point where the curve bends")
print("- This is where adding more clusters gives diminishing returns")
print("- The optimal K is typically at the elbow")
print("\nWCSS/Inertia values:")
for k, wcss in zip(k_range, wcss_list):
    print(f"K={k}: {wcss:.4f}")
print("\nDistortion values:")
for k, dist in zip(k_range, distortion_list):
    print(f"K={k}: {dist:.4f}")
# Out:
# ============================================================
# ELBOW METHOD - Finding Optimal K
# ============================================================
#
# ============================================================
# Testing K = 1
# ============================================================
# Center 1 initialized at index 102
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# K = 1: WCSS (Inertia) = 17070.0000, Distortion = 30.0000, Converged in 2 epochs
#
# ============================================================
# Testing K = 2
# ============================================================
# Center 1 initialized at index 102
# Center 2 initialized at index 432
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# K = 2: WCSS (Inertia) = 11595.5266, Distortion = 20.3788, Converged in 4 epochs
#
# ============================================================
# Testing K = 3
# ============================================================
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# K = 3: WCSS (Inertia) = 10061.7978, Distortion = 17.6833, Converged in 10 epochs
#
# ============================================================
# Testing K = 4
# ============================================================
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# K = 4: WCSS (Inertia) = 9339.3911, Distortion = 16.4137, Converged in 6 epochs
#
# ============================================================
# Testing K = 5
# ============================================================
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# K = 5: WCSS (Inertia) = 8885.0056, Distortion = 15.6151, Converged in 9 epochs
#
# ============================================================
# Testing K = 6
# ============================================================
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# K = 6: WCSS (Inertia) = 8394.4252, Distortion = 14.7529, Converged in 9 epochs
#
# ============================================================
# Testing K = 7
# ============================================================
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# K = 7: WCSS (Inertia) = 7849.3084, Distortion = 13.7949, Converged in 15 epochs
#
# ============================================================
# Testing K = 8
# ============================================================
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# K = 8: WCSS (Inertia) = 7276.9485, Distortion = 12.7890, Converged in 20 epochs
#
# ============================================================
# Testing K = 9
# ============================================================
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# K = 9: WCSS (Inertia) = 7364.3734, Distortion = 12.9427, Converged in 25 epochs
#
# ============================================================
# Testing K = 10
# ============================================================
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# K = 10: WCSS (Inertia) = 6873.5905, Distortion = 12.0801, Converged in 33 epochs
#
# ============================================================
# PLOTTING RESULTS
# ============================================================
# Elbow Method Complete!
#
# Interpretation:
# - Look for the 'elbow' point where the curve bends
# - This is where adding more clusters gives diminishing returns
# - The optimal K is typically at the elbow
#
# WCSS/Inertia values:
# K=1: 17070.0000
# K=2: 11595.5266
# K=3: 10061.7978
# K=4: 9339.3911
# K=5: 8885.0056
# K=6: 8394.4252
# K=7: 7849.3084
# K=8: 7276.9485
# K=9: 7364.3734
# K=10: 6873.5905
#
# Distortion values:
# K=1: 30.0000
# K=2: 20.3788
# K=3: 17.6833
# K=4: 16.4137
# K=5: 15.6151
# K=6: 14.7529
# K=7: 13.7949
# K=8: 12.7890
# K=9: 12.9427
# K=10: 12.0801

# %% [markdown]
# elbow method = called elbow because for sure when i increase k the wcc will convirge or error will beocme lower
# WCSS : WCSS measures how compact the clusters are. It is the sum of squared distances between each point and the centroid of the cluster it belongs to.
# Inertia : same as WCSS
# Distortion : is a normalized version of WCSS just to make it easier to compare between different data sets so distortion = 1/n WCSS and remeber they have graph of distortion and WCSS becuse scaling does not change shape of graph

# %%
def compute_distance_matrix(X):
    n_samples = X.shape[0]
    distances = np.zeros((n_samples, n_samples))

    for i in range(n_samples):
        for j in range(i + 1, n_samples):
            diff = X[i] - X[j]
            dist = np.sqrt(np.sum(diff ** 2))
            distances[i, j] = dist
            distances[j, i] = dist

    return distances

def silhouette_score_readable(X, labels):
    n_samples = X.shape[0]
    unique_clusters = np.unique(labels)

    if len(unique_clusters) < 2:
        raise ValueError("Silhouette score is undefined for k < 2")

    # Precompute all distances
    distances = compute_distance_matrix(X)

    silhouette_values = []

    for i in range(n_samples):
        current_cluster = labels[i]

        # ---- a(i): mean distance to points in the same cluster ----
        intra_cluster_distances = []

        for j in range(n_samples):
            if labels[j] == current_cluster and j != i:
                intra_cluster_distances.append(distances[i, j])

        if len(intra_cluster_distances) == 0:
            a_i = 0.0
        else:
            a_i = sum(intra_cluster_distances) / len(intra_cluster_distances)

        # ---- b(i): minimum mean distance to other clusters ----
        b_i = float("inf")

        for cluster in unique_clusters:
            if cluster == current_cluster:
                continue

            inter_cluster_distances = []

            for j in range(n_samples):
                if labels[j] == cluster:
                    inter_cluster_distances.append(distances[i, j])

            if len(inter_cluster_distances) > 0:
                mean_distance = sum(inter_cluster_distances) / len(inter_cluster_distances)
                b_i = min(b_i, mean_distance)

        # ---- silhouette for point i ----
        s_i = (b_i - a_i) / max(a_i, b_i)
        silhouette_values.append(s_i)

    # ---- overall silhouette score ----
    return sum(silhouette_values) / len(silhouette_values)

import matplotlib.pyplot as plt

K_values = range(2, 30)
silhouette_scores = []

for k in K_values:
    # Initialize centroids (K-Means++)
    init_centers = kmeans_plusplus_init(X_data, k=k, random_state=42)

    # Run K-Means
    centers, labels, _ = kmeans(
        X_data,
        k,
        init_centers,
        epochs=100,
        verbose=False
    )

    # Compute silhouette score (manual, readable version)
    score = silhouette_score_readable(X_data, labels)
    silhouette_scores.append(score)

plt.figure(figsize=(8, 5))
plt.plot(list(K_values), silhouette_scores, marker='o')
plt.xlabel("Number of clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Score vs Number of Clusters (Manual Implementation)")
plt.grid(True)
plt.show()
# Out:
# Center 1 initialized at index 102
# Center 2 initialized at index 432
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
#
# K-means++ initialization complete!
# Initial centers shape: (11, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
#
# K-means++ initialization complete!
# Initial centers shape: (12, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
#
# K-means++ initialization complete!
# Initial centers shape: (13, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
#
# K-means++ initialization complete!
# Initial centers shape: (14, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
#
# K-means++ initialization complete!
# Initial centers shape: (15, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
#
# K-means++ initialization complete!
# Initial centers shape: (16, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
#
# K-means++ initialization complete!
# Initial centers shape: (17, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
#
# K-means++ initialization complete!
# Initial centers shape: (18, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
# Center 19 initialized at index 3
#
# K-means++ initialization complete!
# Initial centers shape: (19, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
# Center 19 initialized at index 3
# Center 20 initialized at index 11
#
# K-means++ initialization complete!
# Initial centers shape: (20, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
# Center 19 initialized at index 3
# Center 20 initialized at index 11
# Center 21 initialized at index 275
#
# K-means++ initialization complete!
# Initial centers shape: (21, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
# Center 19 initialized at index 3
# Center 20 initialized at index 11
# Center 21 initialized at index 275
# Center 22 initialized at index 202
#
# K-means++ initialization complete!
# Initial centers shape: (22, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
# Center 19 initialized at index 3
# Center 20 initialized at index 11
# Center 21 initialized at index 275
# Center 22 initialized at index 202
# Center 23 initialized at index 21
#
# K-means++ initialization complete!
# Initial centers shape: (23, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
# Center 19 initialized at index 3
# Center 20 initialized at index 11
# Center 21 initialized at index 275
# Center 22 initialized at index 202
# Center 23 initialized at index 21
# Center 24 initialized at index 559
#
# K-means++ initialization complete!
# Initial centers shape: (24, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
# Center 19 initialized at index 3
# Center 20 initialized at index 11
# Center 21 initialized at index 275
# Center 22 initialized at index 202
# Center 23 initialized at index 21
# Center 24 initialized at index 559
# Center 25 initialized at index 113
#
# K-means++ initialization complete!
# Initial centers shape: (25, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
# Center 19 initialized at index 3
# Center 20 initialized at index 11
# Center 21 initialized at index 275
# Center 22 initialized at index 202
# Center 23 initialized at index 21
# Center 24 initialized at index 559
# Center 25 initialized at index 113
# Center 26 initialized at index 42
#
# K-means++ initialization complete!
# Initial centers shape: (26, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
# Center 19 initialized at index 3
# Center 20 initialized at index 11
# Center 21 initialized at index 275
# Center 22 initialized at index 202
# Center 23 initialized at index 21
# Center 24 initialized at index 559
# Center 25 initialized at index 113
# Center 26 initialized at index 42
# Center 27 initialized at index 338
#
# K-means++ initialization complete!
# Initial centers shape: (27, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
# Center 19 initialized at index 3
# Center 20 initialized at index 11
# Center 21 initialized at index 275
# Center 22 initialized at index 202
# Center 23 initialized at index 21
# Center 24 initialized at index 559
# Center 25 initialized at index 113
# Center 26 initialized at index 42
# Center 27 initialized at index 338
# Center 28 initialized at index 194
#
# K-means++ initialization complete!
# Initial centers shape: (28, 30)
# Center 1 initialized at index 102
# Center 2 initialized at index 432
# Center 3 initialized at index 81
# Center 4 initialized at index 426
# Center 5 initialized at index 294
# Center 6 initialized at index 212
# Center 7 initialized at index 40
# Center 8 initialized at index 213
# Center 9 initialized at index 152
# Center 10 initialized at index 64
# Center 11 initialized at index 339
# Center 12 initialized at index 13
# Center 13 initialized at index 388
# Center 14 initialized at index 539
# Center 15 initialized at index 0
# Center 16 initialized at index 567
# Center 17 initialized at index 323
# Center 18 initialized at index 319
# Center 19 initialized at index 3
# Center 20 initialized at index 11
# Center 21 initialized at index 275
# Center 22 initialized at index 202
# Center 23 initialized at index 21
# Center 24 initialized at index 559
# Center 25 initialized at index 113
# Center 26 initialized at index 42
# Center 27 initialized at index 338
# Center 28 initialized at index 194
# Center 29 initialized at index 562
#
# K-means++ initialization complete!
# Initial centers shape: (29, 30)

# %% [markdown]
# Informally, uniformly distributed data means that points occupy the space evenly, with no region having higher density or structure than another. There are no natural clusters, and any grouping observed is due to randomness rather than underlying structure like running your k-means on data does not respect you assumptions , but if you run k-means on data that respect you are assumption and have meangiful structure it should be different
#
# ![Screenshot From 2025-12-25 02-02-19.png](data:image/png;base64,...)
#
# ![Screenshot From 2025-12-25 02-02-50.png](data:image/png;base64,...)**

# %%
def compute_feature_bounds(X):
    feature_mins = np.min(X, axis=0)
    feature_maxs = np.max(X, axis=0)
    return feature_mins, feature_maxs

def generate_uniform_reference(X, n_samples):
    feature_mins, feature_maxs = compute_feature_bounds(X)
    n_features = X.shape[1]

    reference_data = np.zeros((n_samples, n_features))

    for j in range(n_features):
        reference_data[:, j] = np.random.uniform(
            feature_mins[j],
            feature_maxs[j],
            size=n_samples
        )

    return reference_data
def compute_inertia(X, k, epochs=100):
    init_centers = kmeans_plusplus_init(X, k=k)
    _, _, inertia_history = kmeans(
        X, k, init_centers, epochs=epochs, verbose=False
    )
    return inertia_history[-1]

def gap_statistic(X, k_max, B=10, epochs=100):
    n_samples = X.shape[0]

    gap_values = []
    sk_values = []

    for k in range(1, k_max + 1):
        print(f"Computing Gap Statistic for k = {k}")

        # ---- Real data inertia ----
        Wk = compute_inertia(X, k, epochs)
        log_Wk = np.log(Wk)

        # ---- Reference data inertias ----
        log_Wk_refs = []

        for b in range(B):
            X_ref = generate_uniform_reference(X, n_samples)
            Wk_ref = compute_inertia(X_ref, k, epochs)
            log_Wk_refs.append(np.log(Wk_ref))

        # ---- Gap value ----
        gap_k = np.mean(log_Wk_refs) - log_Wk
        gap_values.append(gap_k)

        # ---- Standard deviation ----
        std_k = np.std(log_Wk_refs)
        sk = np.sqrt(1 + 1 / B) * std_k
        sk_values.append(sk)

    return gap_values, sk_values
k_max = 10
B = 10  # number of reference datasets

gap_values, sk_values = gap_statistic(
    X_data,
    k_max=k_max,
    B=B,
    epochs=100
)
import matplotlib.pyplot as plt

k_values = list(range(1, k_max + 1))

plt.figure(figsize=(8, 5))
plt.plot(k_values, gap_values, marker='o')
plt.xlabel("Number of clusters (k)")
plt.ylabel("Gap Statistic")
plt.title("Gap Statistic vs Number of Clusters")
plt.grid(True)
plt.show()
def select_optimal_k(gap_values, sk_values):
    for k in range(len(gap_values) - 1):
        if gap_values[k] >= gap_values[k + 1] - sk_values[k + 1]:
            return k + 1  # +1 because k starts at 1
    return len(gap_values)
optimal_k = select_optimal_k(gap_values, sk_values)
print(f"Optimal k according to Gap Statistic: {optimal_k}")
# Out:
# Computing Gap Statistic for k = 1
# Center 1 initialized at index 504
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# Center 1 initialized at index 65
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# Center 1 initialized at index 337
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# Center 1 initialized at index 222
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# Center 1 initialized at index 560
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# Center 1 initialized at index 398
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# Center 1 initialized at index 533
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# Center 1 initialized at index 293
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# Center 1 initialized at index 107
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# Center 1 initialized at index 139
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# Center 1 initialized at index 318
#
# K-means++ initialization complete!
# Initial centers shape: (1, 30)
# Computing Gap Statistic for k = 2
# Center 1 initialized at index 483
# Center 2 initialized at index 85
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 450
# Center 2 initialized at index 131
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 249
# Center 2 initialized at index 94
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 329
# Center 2 initialized at index 66
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 477
# Center 2 initialized at index 200
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 24
# Center 2 initialized at index 405
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 213
# Center 2 initialized at index 548
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 105
# Center 2 initialized at index 504
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 547
# Center 2 initialized at index 337
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 134
# Center 2 initialized at index 498
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 391
# Center 2 initialized at index 542
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Computing Gap Statistic for k = 3
# Center 1 initialized at index 483
# Center 2 initialized at index 18
# Center 3 initialized at index 323
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Center 1 initialized at index 97
# Center 2 initialized at index 269
# Center 3 initialized at index 207
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Center 1 initialized at index 325
# Center 2 initialized at index 193
# Center 3 initialized at index 402
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Center 1 initialized at index 248
# Center 2 initialized at index 568
# Center 3 initialized at index 444
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Center 1 initialized at index 508
# Center 2 initialized at index 559
# Center 3 initialized at index 354
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Center 1 initialized at index 37
# Center 2 initialized at index 437
# Center 3 initialized at index 413
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Center 1 initialized at index 184
# Center 2 initialized at index 175
# Center 3 initialized at index 52
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Center 1 initialized at index 275
# Center 2 initialized at index 40
# Center 3 initialized at index 529
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Center 1 initialized at index 381
# Center 2 initialized at index 41
# Center 3 initialized at index 496
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Center 1 initialized at index 20
# Center 2 initialized at index 271
# Center 3 initialized at index 421
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Center 1 initialized at index 33
# Center 2 initialized at index 90
# Center 3 initialized at index 304
#
# K-means++ initialization complete!
# Initial centers shape: (3, 30)
# Computing Gap Statistic for k = 4
# Center 1 initialized at index 15
# Center 2 initialized at index 505
# Center 3 initialized at index 318
# Center 4 initialized at index 278
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Center 1 initialized at index 212
# Center 2 initialized at index 371
# Center 3 initialized at index 85
# Center 4 initialized at index 414
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Center 1 initialized at index 464
# Center 2 initialized at index 219
# Center 3 initialized at index 229
# Center 4 initialized at index 197
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Center 1 initialized at index 145
# Center 2 initialized at index 75
# Center 3 initialized at index 179
# Center 4 initialized at index 412
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Center 1 initialized at index 206
# Center 2 initialized at index 80
# Center 3 initialized at index 409
# Center 4 initialized at index 208
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Center 1 initialized at index 410
# Center 2 initialized at index 2
# Center 3 initialized at index 248
# Center 4 initialized at index 254
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Center 1 initialized at index 428
# Center 2 initialized at index 275
# Center 3 initialized at index 196
# Center 4 initialized at index 303
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Center 1 initialized at index 407
# Center 2 initialized at index 160
# Center 3 initialized at index 567
# Center 4 initialized at index 379
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Center 1 initialized at index 394
# Center 2 initialized at index 521
# Center 3 initialized at index 20
# Center 4 initialized at index 212
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Center 1 initialized at index 293
# Center 2 initialized at index 262
# Center 3 initialized at index 208
# Center 4 initialized at index 340
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Center 1 initialized at index 159
# Center 2 initialized at index 20
# Center 3 initialized at index 219
# Center 4 initialized at index 163
#
# K-means++ initialization complete!
# Initial centers shape: (4, 30)
# Computing Gap Statistic for k = 5
# Center 1 initialized at index 467
# Center 2 initialized at index 180
# Center 3 initialized at index 212
# Center 4 initialized at index 269
# Center 5 initialized at index 68
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Center 1 initialized at index 486
# Center 2 initialized at index 7
# Center 3 initialized at index 164
# Center 4 initialized at index 41
# Center 5 initialized at index 72
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Center 1 initialized at index 279
# Center 2 initialized at index 342
# Center 3 initialized at index 330
# Center 4 initialized at index 246
# Center 5 initialized at index 466
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Center 1 initialized at index 161
# Center 2 initialized at index 506
# Center 3 initialized at index 545
# Center 4 initialized at index 266
# Center 5 initialized at index 329
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Center 1 initialized at index 231
# Center 2 initialized at index 21
# Center 3 initialized at index 472
# Center 4 initialized at index 321
# Center 5 initialized at index 308
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Center 1 initialized at index 258
# Center 2 initialized at index 373
# Center 3 initialized at index 15
# Center 4 initialized at index 158
# Center 5 initialized at index 520
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Center 1 initialized at index 371
# Center 2 initialized at index 142
# Center 3 initialized at index 45
# Center 4 initialized at index 146
# Center 5 initialized at index 195
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Center 1 initialized at index 272
# Center 2 initialized at index 566
# Center 3 initialized at index 166
# Center 4 initialized at index 288
# Center 5 initialized at index 58
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Center 1 initialized at index 47
# Center 2 initialized at index 198
# Center 3 initialized at index 563
# Center 4 initialized at index 306
# Center 5 initialized at index 195
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Center 1 initialized at index 453
# Center 2 initialized at index 344
# Center 3 initialized at index 374
# Center 4 initialized at index 285
# Center 5 initialized at index 9
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Center 1 initialized at index 169
# Center 2 initialized at index 78
# Center 3 initialized at index 99
# Center 4 initialized at index 249
# Center 5 initialized at index 229
#
# K-means++ initialization complete!
# Initial centers shape: (5, 30)
# Computing Gap Statistic for k = 6
# Center 1 initialized at index 132
# Center 2 initialized at index 190
# Center 3 initialized at index 388
# Center 4 initialized at index 111
# Center 5 initialized at index 454
# Center 6 initialized at index 343
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Center 1 initialized at index 389
# Center 2 initialized at index 187
# Center 3 initialized at index 381
# Center 4 initialized at index 511
# Center 5 initialized at index 42
# Center 6 initialized at index 498
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Center 1 initialized at index 82
# Center 2 initialized at index 508
# Center 3 initialized at index 431
# Center 4 initialized at index 191
# Center 5 initialized at index 192
# Center 6 initialized at index 143
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Center 1 initialized at index 218
# Center 2 initialized at index 507
# Center 3 initialized at index 32
# Center 4 initialized at index 311
# Center 5 initialized at index 401
# Center 6 initialized at index 544
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Center 1 initialized at index 305
# Center 2 initialized at index 28
# Center 3 initialized at index 237
# Center 4 initialized at index 238
# Center 5 initialized at index 55
# Center 6 initialized at index 77
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Center 1 initialized at index 153
# Center 2 initialized at index 451
# Center 3 initialized at index 168
# Center 4 initialized at index 216
# Center 5 initialized at index 377
# Center 6 initialized at index 73
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Center 1 initialized at index 31
# Center 2 initialized at index 326
# Center 3 initialized at index 209
# Center 4 initialized at index 457
# Center 5 initialized at index 493
# Center 6 initialized at index 20
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Center 1 initialized at index 317
# Center 2 initialized at index 201
# Center 3 initialized at index 507
# Center 4 initialized at index 235
# Center 5 initialized at index 240
# Center 6 initialized at index 226
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Center 1 initialized at index 560
# Center 2 initialized at index 356
# Center 3 initialized at index 382
# Center 4 initialized at index 418
# Center 5 initialized at index 194
# Center 6 initialized at index 177
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Center 1 initialized at index 10
# Center 2 initialized at index 321
# Center 3 initialized at index 138
# Center 4 initialized at index 464
# Center 5 initialized at index 414
# Center 6 initialized at index 444
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Center 1 initialized at index 539
# Center 2 initialized at index 47
# Center 3 initialized at index 122
# Center 4 initialized at index 336
# Center 5 initialized at index 168
# Center 6 initialized at index 20
#
# K-means++ initialization complete!
# Initial centers shape: (6, 30)
# Computing Gap Statistic for k = 7
# Center 1 initialized at index 86
# Center 2 initialized at index 511
# Center 3 initialized at index 229
# Center 4 initialized at index 461
# Center 5 initialized at index 290
# Center 6 initialized at index 560
# Center 7 initialized at index 164
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Center 1 initialized at index 194
# Center 2 initialized at index 127
# Center 3 initialized at index 223
# Center 4 initialized at index 192
# Center 5 initialized at index 490
# Center 6 initialized at index 453
# Center 7 initialized at index 131
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Center 1 initialized at index 537
# Center 2 initialized at index 531
# Center 3 initialized at index 360
# Center 4 initialized at index 94
# Center 5 initialized at index 511
# Center 6 initialized at index 484
# Center 7 initialized at index 231
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Center 1 initialized at index 447
# Center 2 initialized at index 440
# Center 3 initialized at index 255
# Center 4 initialized at index 20
# Center 5 initialized at index 541
# Center 6 initialized at index 39
# Center 7 initialized at index 396
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Center 1 initialized at index 338
# Center 2 initialized at index 558
# Center 3 initialized at index 171
# Center 4 initialized at index 21
# Center 5 initialized at index 212
# Center 6 initialized at index 197
# Center 7 initialized at index 397
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Center 1 initialized at index 195
# Center 2 initialized at index 322
# Center 3 initialized at index 50
# Center 4 initialized at index 124
# Center 5 initialized at index 38
# Center 6 initialized at index 43
# Center 7 initialized at index 243
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Center 1 initialized at index 75
# Center 2 initialized at index 274
# Center 3 initialized at index 143
# Center 4 initialized at index 156
# Center 5 initialized at index 339
# Center 6 initialized at index 133
# Center 7 initialized at index 525
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Center 1 initialized at index 369
# Center 2 initialized at index 12
# Center 3 initialized at index 466
# Center 4 initialized at index 7
# Center 5 initialized at index 518
# Center 6 initialized at index 385
# Center 7 initialized at index 561
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Center 1 initialized at index 154
# Center 2 initialized at index 385
# Center 3 initialized at index 427
# Center 4 initialized at index 547
# Center 5 initialized at index 271
# Center 6 initialized at index 264
# Center 7 initialized at index 10
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Center 1 initialized at index 457
# Center 2 initialized at index 41
# Center 3 initialized at index 553
# Center 4 initialized at index 161
# Center 5 initialized at index 69
# Center 6 initialized at index 217
# Center 7 initialized at index 73
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Center 1 initialized at index 442
# Center 2 initialized at index 188
# Center 3 initialized at index 158
# Center 4 initialized at index 79
# Center 5 initialized at index 535
# Center 6 initialized at index 393
# Center 7 initialized at index 46
#
# K-means++ initialization complete!
# Initial centers shape: (7, 30)
# Computing Gap Statistic for k = 8
# Center 1 initialized at index 264
# Center 2 initialized at index 301
# Center 3 initialized at index 154
# Center 4 initialized at index 316
# Center 5 initialized at index 300
# Center 6 initialized at index 34
# Center 7 initialized at index 496
# Center 8 initialized at index 68
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Center 1 initialized at index 156
# Center 2 initialized at index 205
# Center 3 initialized at index 526
# Center 4 initialized at index 97
# Center 5 initialized at index 539
# Center 6 initialized at index 558
# Center 7 initialized at index 245
# Center 8 initialized at index 348
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Center 1 initialized at index 170
# Center 2 initialized at index 384
# Center 3 initialized at index 226
# Center 4 initialized at index 371
# Center 5 initialized at index 411
# Center 6 initialized at index 85
# Center 7 initialized at index 86
# Center 8 initialized at index 557
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Center 1 initialized at index 112
# Center 2 initialized at index 192
# Center 3 initialized at index 160
# Center 4 initialized at index 541
# Center 5 initialized at index 277
# Center 6 initialized at index 421
# Center 7 initialized at index 101
# Center 8 initialized at index 187
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Center 1 initialized at index 266
# Center 2 initialized at index 101
# Center 3 initialized at index 46
# Center 4 initialized at index 488
# Center 5 initialized at index 222
# Center 6 initialized at index 100
# Center 7 initialized at index 369
# Center 8 initialized at index 398
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Center 1 initialized at index 521
# Center 2 initialized at index 45
# Center 3 initialized at index 240
# Center 4 initialized at index 560
# Center 5 initialized at index 237
# Center 6 initialized at index 476
# Center 7 initialized at index 74
# Center 8 initialized at index 153
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Center 1 initialized at index 454
# Center 2 initialized at index 532
# Center 3 initialized at index 238
# Center 4 initialized at index 154
# Center 5 initialized at index 396
# Center 6 initialized at index 41
# Center 7 initialized at index 8
# Center 8 initialized at index 247
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Center 1 initialized at index 267
# Center 2 initialized at index 282
# Center 3 initialized at index 91
# Center 4 initialized at index 555
# Center 5 initialized at index 221
# Center 6 initialized at index 12
# Center 7 initialized at index 464
# Center 8 initialized at index 266
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Center 1 initialized at index 23
# Center 2 initialized at index 269
# Center 3 initialized at index 506
# Center 4 initialized at index 236
# Center 5 initialized at index 256
# Center 6 initialized at index 3
# Center 7 initialized at index 108
# Center 8 initialized at index 425
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Center 1 initialized at index 0
# Center 2 initialized at index 495
# Center 3 initialized at index 374
# Center 4 initialized at index 506
# Center 5 initialized at index 370
# Center 6 initialized at index 382
# Center 7 initialized at index 552
# Center 8 initialized at index 471
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Center 1 initialized at index 27
# Center 2 initialized at index 81
# Center 3 initialized at index 294
# Center 4 initialized at index 372
# Center 5 initialized at index 374
# Center 6 initialized at index 278
# Center 7 initialized at index 247
# Center 8 initialized at index 123
#
# K-means++ initialization complete!
# Initial centers shape: (8, 30)
# Computing Gap Statistic for k = 9
# Center 1 initialized at index 498
# Center 2 initialized at index 208
# Center 3 initialized at index 175
# Center 4 initialized at index 438
# Center 5 initialized at index 192
# Center 6 initialized at index 257
# Center 7 initialized at index 122
# Center 8 initialized at index 461
# Center 9 initialized at index 517
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Center 1 initialized at index 495
# Center 2 initialized at index 316
# Center 3 initialized at index 444
# Center 4 initialized at index 453
# Center 5 initialized at index 41
# Center 6 initialized at index 302
# Center 7 initialized at index 12
# Center 8 initialized at index 90
# Center 9 initialized at index 331
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Center 1 initialized at index 406
# Center 2 initialized at index 475
# Center 3 initialized at index 59
# Center 4 initialized at index 60
# Center 5 initialized at index 341
# Center 6 initialized at index 241
# Center 7 initialized at index 211
# Center 8 initialized at index 178
# Center 9 initialized at index 412
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Center 1 initialized at index 65
# Center 2 initialized at index 506
# Center 3 initialized at index 213
# Center 4 initialized at index 412
# Center 5 initialized at index 522
# Center 6 initialized at index 45
# Center 7 initialized at index 202
# Center 8 initialized at index 360
# Center 9 initialized at index 338
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Center 1 initialized at index 442
# Center 2 initialized at index 140
# Center 3 initialized at index 227
# Center 4 initialized at index 411
# Center 5 initialized at index 214
# Center 6 initialized at index 303
# Center 7 initialized at index 511
# Center 8 initialized at index 311
# Center 9 initialized at index 23
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Center 1 initialized at index 264
# Center 2 initialized at index 83
# Center 3 initialized at index 404
# Center 4 initialized at index 214
# Center 5 initialized at index 561
# Center 6 initialized at index 111
# Center 7 initialized at index 333
# Center 8 initialized at index 232
# Center 9 initialized at index 81
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Center 1 initialized at index 58
# Center 2 initialized at index 516
# Center 3 initialized at index 345
# Center 4 initialized at index 211
# Center 5 initialized at index 338
# Center 6 initialized at index 382
# Center 7 initialized at index 198
# Center 8 initialized at index 514
# Center 9 initialized at index 353
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Center 1 initialized at index 105
# Center 2 initialized at index 292
# Center 3 initialized at index 464
# Center 4 initialized at index 106
# Center 5 initialized at index 175
# Center 6 initialized at index 251
# Center 7 initialized at index 272
# Center 8 initialized at index 237
# Center 9 initialized at index 127
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Center 1 initialized at index 380
# Center 2 initialized at index 501
# Center 3 initialized at index 229
# Center 4 initialized at index 351
# Center 5 initialized at index 204
# Center 6 initialized at index 106
# Center 7 initialized at index 385
# Center 8 initialized at index 439
# Center 9 initialized at index 349
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Center 1 initialized at index 391
# Center 2 initialized at index 548
# Center 3 initialized at index 421
# Center 4 initialized at index 517
# Center 5 initialized at index 425
# Center 6 initialized at index 213
# Center 7 initialized at index 207
# Center 8 initialized at index 110
# Center 9 initialized at index 135
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Center 1 initialized at index 349
# Center 2 initialized at index 444
# Center 3 initialized at index 550
# Center 4 initialized at index 492
# Center 5 initialized at index 463
# Center 6 initialized at index 256
# Center 7 initialized at index 46
# Center 8 initialized at index 96
# Center 9 initialized at index 333
#
# K-means++ initialization complete!
# Initial centers shape: (9, 30)
# Computing Gap Statistic for k = 10
# Center 1 initialized at index 246
# Center 2 initialized at index 380
# Center 3 initialized at index 61
# Center 4 initialized at index 368
# Center 5 initialized at index 68
# Center 6 initialized at index 333
# Center 7 initialized at index 85
# Center 8 initialized at index 122
# Center 9 initialized at index 63
# Center 10 initialized at index 108
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Center 1 initialized at index 241
# Center 2 initialized at index 377
# Center 3 initialized at index 170
# Center 4 initialized at index 556
# Center 5 initialized at index 146
# Center 6 initialized at index 293
# Center 7 initialized at index 206
# Center 8 initialized at index 285
# Center 9 initialized at index 149
# Center 10 initialized at index 378
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Center 1 initialized at index 401
# Center 2 initialized at index 86
# Center 3 initialized at index 470
# Center 4 initialized at index 499
# Center 5 initialized at index 120
# Center 6 initialized at index 192
# Center 7 initialized at index 198
# Center 8 initialized at index 502
# Center 9 initialized at index 37
# Center 10 initialized at index 226
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Center 1 initialized at index 162
# Center 2 initialized at index 121
# Center 3 initialized at index 354
# Center 4 initialized at index 167
# Center 5 initialized at index 175
# Center 6 initialized at index 324
# Center 7 initialized at index 538
# Center 8 initialized at index 177
# Center 9 initialized at index 376
# Center 10 initialized at index 534
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Center 1 initialized at index 127
# Center 2 initialized at index 558
# Center 3 initialized at index 315
# Center 4 initialized at index 311
# Center 5 initialized at index 271
# Center 6 initialized at index 181
# Center 7 initialized at index 346
# Center 8 initialized at index 230
# Center 9 initialized at index 551
# Center 10 initialized at index 261
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Center 1 initialized at index 266
# Center 2 initialized at index 298
# Center 3 initialized at index 219
# Center 4 initialized at index 385
# Center 5 initialized at index 441
# Center 6 initialized at index 250
# Center 7 initialized at index 285
# Center 8 initialized at index 29
# Center 9 initialized at index 229
# Center 10 initialized at index 439
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Center 1 initialized at index 558
# Center 2 initialized at index 176
# Center 3 initialized at index 525
# Center 4 initialized at index 512
# Center 5 initialized at index 131
# Center 6 initialized at index 223
# Center 7 initialized at index 179
# Center 8 initialized at index 482
# Center 9 initialized at index 466
# Center 10 initialized at index 125
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Center 1 initialized at index 287
# Center 2 initialized at index 61
# Center 3 initialized at index 556
# Center 4 initialized at index 291
# Center 5 initialized at index 327
# Center 6 initialized at index 243
# Center 7 initialized at index 216
# Center 8 initialized at index 179
# Center 9 initialized at index 188
# Center 10 initialized at index 169
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Center 1 initialized at index 230
# Center 2 initialized at index 396
# Center 3 initialized at index 177
# Center 4 initialized at index 364
# Center 5 initialized at index 142
# Center 6 initialized at index 258
# Center 7 initialized at index 20
# Center 8 initialized at index 536
# Center 9 initialized at index 308
# Center 10 initialized at index 390
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Center 1 initialized at index 188
# Center 2 initialized at index 275
# Center 3 initialized at index 400
# Center 4 initialized at index 509
# Center 5 initialized at index 7
# Center 6 initialized at index 27
# Center 7 initialized at index 58
# Center 8 initialized at index 191
# Center 9 initialized at index 99
# Center 10 initialized at index 270
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Center 1 initialized at index 338
# Center 2 initialized at index 185
# Center 3 initialized at index 461
# Center 4 initialized at index 18
# Center 5 initialized at index 183
# Center 6 initialized at index 105
# Center 7 initialized at index 248
# Center 8 initialized at index 418
# Center 9 initialized at index 427
# Center 10 initialized at index 362
#
# K-means++ initialization complete!
# Initial centers shape: (10, 30)
# Optimal k according to Gap Statistic: 6

# %%
import numpy as np

def random_init(X, k, random_state=None):

    if random_state is not None:
        np.random.seed(random_state)

    n_samples = X.shape[0]
    indices = np.random.choice(n_samples, k, replace=False)
    centers = X[indices]
    return centers

k = 2  # We know Breast Cancer dataset is binary
epochs = 100
runs = 10  # repeat to account for randomness
def run_kmeans_comparison(X, k, epochs, runs):
    random_inertia = []
    kpp_inertia = []

    for run in range(runs):
        # ---- Random Initialization ----
        random_centers = random_init(X, k)
        _, _, inertia_history = kmeans(X, k, random_centers, epochs, verbose=False)
        random_inertia.append(inertia_history[-1])

        # ---- K-Means++ Initialization ----
        kpp_centers = kmeans_plusplus_init(X, k)
        _, _, inertia_history = kmeans(X, k, kpp_centers, epochs, verbose=False)
        kpp_inertia.append(inertia_history[-1])

    return random_inertia, kpp_inertia

random_inertia, kpp_inertia = run_kmeans_comparison(X_data, k=k, epochs=100, runs=10)

print(f"Random init: mean inertia = {np.mean(random_inertia):.2f}, std = {np.std(random_inertia):.2f}")
print(f"K-Means++: mean inertia = {np.mean(kpp_inertia):.2f}, std = {np.std(kpp_inertia):.2f}")
import matplotlib.pyplot as plt

plt.boxplot([random_inertia, kpp_inertia], labels=["Random", "K-Means++"])
plt.ylabel("Final Inertia (SSE)")
plt.title("K-Means Initialization Comparison")
plt.grid(True)
plt.show()
# Out:
# Center 1 initialized at index 333
# Center 2 initialized at index 270
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 432
# Center 2 initialized at index 527
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 314
# Center 2 initialized at index 242
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 560
# Center 2 initialized at index 217
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 521
# Center 2 initialized at index 543
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 408
# Center 2 initialized at index 186
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 45
# Center 2 initialized at index 102
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 258
# Center 2 initialized at index 240
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 539
# Center 2 initialized at index 233
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Center 1 initialized at index 397
# Center 2 initialized at index 212
#
# K-means++ initialization complete!
# Initial centers shape: (2, 30)
# Random init: mean inertia = 11595.67, std = 0.13
# K-Means++: mean inertia = 11595.64, std = 0.14
# /tmp/ipython-input-2157953714.py:39: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([random_inertia, kpp_inertia], labels=["Random", "K-Means++"])

# %% [markdown]
# | Metric                | Random Init | K-Means++ |
# | --------------------- | ----------- | --------- |
# | Mean Inertia          | Higher      | Lower     |
# | Std of Inertia        | Higher      | Lower     |
# | Convergence Speed     | Slower      | Faster    |
# | Stability Across Runs | Poor        | Better    |
